# %%
cd ~/workspace/
# Out:
# /home/itrushkin/workspace

# %%
# !CUDA_VISIBLE_DEVICES=0 fx collaborator start -n one
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# /usr/lib/python3/dist-packages/urllib3/contrib/socks.py:37: DependencyWarning: SOCKS support in urllib3 requires the installation of optional dependencies: specifically, PySocks.  For more information, see https://urllib3.readthedocs.io/en/latest/contrib.html#socks-proxies
#   DependencyWarning
# [16:03:07] INFO     Loading DEFAULTS for section aggregator from file plan/defaults/aggregator.yaml.                                                  ]8;id=1600866187.2444036-727911;file:///home/itrushkin/.local/lib/python3.6/site-packages/fledge/federated/plan/plan.py\plan.py]8;;\:77
#            INFO     Loading DEFAULTS for section assigner from file plan/defaults/assigner.yaml.                                                      ]8;id=1600866187.2460406-198209;file:///home/itrushkin/.local/lib/python3.6/site-packages/fledge/federated/plan/plan.py\plan.py]8;;\:77
# ...
