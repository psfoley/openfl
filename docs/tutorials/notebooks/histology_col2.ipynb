# %%
cd ~/workspace/
# Out:
# /home/itrushkin/workspace

# %%
# !CUDA_VISIBLE_DEVICES=1 fx collaborator start -n two
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# WARNING:tensorflow:From /home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# [13:23:21] INFO     Loading DEFAULTS for section aggregator from file plan/defaults/aggregator.yaml.                                                  ]8;id=1602757401.4488213-459712;file:///home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/fledge/federated/plan/plan.py\plan.py]8;;\:89
# ...
