# %%
cd ~/workspace/
# Out:
# /home/itrushkin/workspace

# %%
# !CUDA_VISIBLE_DEVICES=1 fx collaborator start -n two
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# /usr/lib/python3/dist-packages/urllib3/contrib/socks.py:37: DependencyWarning: SOCKS support in urllib3 requires the installation of optional dependencies: specifically, PySocks.  For more information, see https://urllib3.readthedocs.io/en/latest/contrib.html#socks-proxies
#   DependencyWarning
# [16:03:12] INFO     Loading DEFAULTS for section aggregator from file plan/defaults/aggregator.yaml.                                                  ]8;id=1600866192.8546321-810775;file:///home/itrushkin/.local/lib/python3.6/site-packages/fledge/federated/plan/plan.py\plan.py]8;;\:77
#            INFO     Loading DEFAULTS for section assigner from file plan/defaults/assigner.yaml.                                                      ]8;id=1600866192.856317-583221;file:///home/itrushkin/.local/lib/python3.6/site-packages/fledge/federated/plan/plan.py\plan.py]8;;\:77
# ...
