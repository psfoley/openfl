# %%
# !pip install /home/itrushkin/repos/fledge/
# Out:
# Processing /home/itrushkin/repos/fledge
# ...
#   Created wheel for fledge: filename=fledge-0.1-py3-none-any.whl size=149339 sha256=c490b5d495c08cb37b60eb9f4fd5892c65ee90104a4b2bebbd1fd23feeeaa492
#   Stored in directory: /tmp/pip-ephem-wheel-cache-kme6gro7/wheels/3a/30/9d/a88101effd240e4a8721301bebf95a245eaf4904b55b7ae530
# Successfully built fledge
# ...
#   Attempting uninstall: fledge
#     Found existing installation: fledge 0.1
#     Uninstalling fledge-0.1:
#       Successfully uninstalled fledge-0.1
# ...
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/itrushkin/.virtualenvs/fledge/bin/python -m pip install --upgrade pip' command.

# %%
# !rm -rf ~/workspace
# !fx workspace create --prefix ~/workspace --template torch_cnn_histology
# %cd /home/itrushkin/workspace
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# WARNING:tensorflow:From /home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Creating Workspace Directories
# Creating Workspace Certifications
# Creating Workspace Templates
# No additional requirements for workspace defined. Skipping...
#
# New workspace directory structure:
# workspace
# ├── code
# │   ├── pthistology_inmemory.py
# │   ├── pt_cnn.py
# │   ├── histology_utils.py
# │   ├── requirements.txt
# │   └── __init__.py
# ├── plan
# │   ├── cols.yaml
# │   ├── data.yaml
# │   ├── defaults
# │   │   ├── tasks_keras.yaml
# │   │   ├── tasks_tensorflow.yaml
# │   │   ├── network.yaml
# │   │   ├── collaborator.yaml
# │   │   ├── assigner.yaml
# ...

# %%
# !fx workspace certify
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# WARNING:tensorflow:From /home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Setting Up Certificate Authority...
#
# 1.  Create Root CA
# 1.1 Create Directories
# 1.2 Create Database
# 1.3 Create CA Request
# 1.4 Create CA Certificate
# 2.  Create Signing Certificate
# 2.1 Create Directories
# 2.2 Create Database
# 2.3 Create Signing Certificate CSR
# 2.4 Sign Signing Certificate CSR
# 3   Create Certificate Chain
#
# Done.
#
#  ✔️ OK

# %%
# !fx aggregator generate-cert-request --fqdn nnlicv611.inn.intel.com
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# WARNING:tensorflow:From /home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Creating AGGREGATOR certificate key pair with following settings: CN=nnlicv611.inn.intel.com, SAN=DNS:nnlicv611.inn.intel.com
#   Moving AGGREGATOR certificate key pair to: cert/server
#
#  ✔️ OK

# %%
# !fx aggregator certify -s --fqdn nnlicv611.inn.intel.com
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# WARNING:tensorflow:From /home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# The CSR Hash for file agg_nnlicv611.inn.intel.com.csr =  1b6ef3324ca7b1ab5faec47570fcd16d083f6d875a1b93672f23303d70974d18
#
#  Signing AGGREGATOR certificate key pair
#   Moving AGGREGATOR certificate key pair to: cert/server
#
#  ✔️ OK

# %%
# !fx collaborator generate-cert-request -n one -d 1
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# WARNING:tensorflow:From /home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Creating COLLABORATOR certificate key pair with following settings: CN=one, SAN=DNS:one
#   Moving COLLABORATOR certificate to: cert/col_one
# Archive col_one_to_agg_cert_request.zip with certificate signing request created
# This file should be sent to the certificate authority (typically hosted by the aggregator) for signing
#
#  ✔️ OK

# %%
# !fx collaborator certify -s -n one
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# WARNING:tensorflow:From /home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# The CSR Hash for file col_one.csr =  37fb3ce46defa37cdc260bd43762f03717ba50d7fb5b1ac07567a30a6ebcba34
#
#  Signing COLLABORATOR certificate key pair
#   Moving COLLABORATOR certificate key pair to: cert/client
#
# Registering one in plan/cols.yaml
#
#  ✔️ OK

# %%
# !fx collaborator generate-cert-request -n two -d 2
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# WARNING:tensorflow:From /home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Creating COLLABORATOR certificate key pair with following settings: CN=two, SAN=DNS:two
#   Moving COLLABORATOR certificate to: cert/col_two
# Archive col_two_to_agg_cert_request.zip with certificate signing request created
# This file should be sent to the certificate authority (typically hosted by the aggregator) for signing
#
#  ✔️ OK

# %%
# !fx collaborator certify -s -n two
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# WARNING:tensorflow:From /home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# The CSR Hash for file col_two.csr =  6b272538973c0762b4623d89f8cbbd51fcf0ffa99fb450c9638e4aace33e63c7
#
#  Signing COLLABORATOR certificate key pair
#   Moving COLLABORATOR certificate key pair to: cert/client
#
# Registering two in plan/cols.yaml
#
#  ✔️ OK

# %%
# !fx plan initialize -a nnlicv611.inn.intel.com
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# WARNING:tensorflow:From /home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# [13:21:55] INFO     Loading DEFAULTS for section aggregator from file plan/defaults/aggregator.yaml.                                                  ]8;id=1602757315.3851895-855220;file:///home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/fledge/federated/plan/plan.py\plan.py]8;;\:89
# ...

# %%
# !fx aggregator start
# Out:
# Intel FLedge - Secure Federated Learning at the Edge™
#
# WARNING:tensorflow:From /home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# [13:22:01] INFO     Loading DEFAULTS for section aggregator from file plan/defaults/aggregator.yaml.                                                  ]8;id=1602757321.5382743-252945;file:///home/itrushkin/.virtualenvs/fledge/lib/python3.6/site-packages/fledge/federated/plan/plan.py\plan.py]8;;\:89
# ...
